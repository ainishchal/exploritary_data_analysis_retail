# %% [markdown]
# # Exploratory Data Analysis - Retail
# ## Data Science & Business Analytics Internship
# ### Task - 3
# ###  Nishchal Basyal
#
# ### Problem Statement
# - As a business manager, try to find out the weak areas where you can
# work to make more profit.
# - What all business problems you can derive by exploring the data?

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
#import SampleSuperstoreData
df=pd.read_csv("SampleSuperstore.csv")
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# ### Exploritary Data Analysis

# %%
df.tail(20)
# Out:
#            Ship Mode      Segment        Country          City       State  \
# 9974  Standard Class  Home Office  United States   Los Angeles  California
# 9975  Standard Class  Home Office  United States   Los Angeles  California
# 9976  Standard Class  Home Office  United States   Los Angeles  California
# 9977  Standard Class  Home Office  United States   Los Angeles  California
# 9978  Standard Class  Home Office  United States   Los Angeles  California
# 9979  Standard Class  Home Office  United States   Los Angeles  California
# 9980    Second Class     Consumer  United States     Lafayette   Louisiana
# 9981     First Class     Consumer  United States     Fairfield        Ohio
# 9982  Standard Class     Consumer  United States  Grand Rapids    Michigan
# 9983  Standard Class     Consumer  United States  Grand Rapids    Michigan
# 9984  Standard Class     Consumer  United States    Long Beach    New York
# 9985  Standard Class     Consumer  United States    Long Beach    New York
# 9986  Standard Class     Consumer  United States   Los Angeles  California
# 9987  Standard Class    Corporate  United States        Athens     Georgia
# 9988  Standard Class    Corporate  United States        Athens     Georgia
# 9989    Second Class     Consumer  United States         Miami     Florida
# 9990  Standard Class     Consumer  United States    Costa Mesa  California
# 9991  Standard Class     Consumer  United States    Costa Mesa  California
# 9992  Standard Class     Consumer  United States    Costa Mesa  California
# 9993    Second Class     Consumer  United States   Westminster  California
#
#       Postal Code   Region         Category Sub-Category    Sales  Quantity  \
# 9974        90032     West  Office Supplies          Art   18.690         7
# 9975        90032     West  Office Supplies        Paper   13.360         2
# 9976        90032     West       Technology       Phones  249.584         2
# 9977        90032     West  Office Supplies    Fasteners   13.860         7
# 9978        90032     West  Office Supplies      Binders   13.376         4
# 9979        90032     West  Office Supplies      Binders  437.472        14
# 9980        70506    South        Furniture       Tables   85.980         1
# 9981        45014     East  Office Supplies       Labels   16.520         5
# 9982        49505  Central  Office Supplies        Paper   35.560         7
# 9983        49505  Central       Technology       Phones   97.980         2
# 9984        11561     East  Office Supplies       Labels   31.500        10
# 9985        11561     East  Office Supplies     Supplies   55.600         4
# 9986        90008     West       Technology  Accessories   36.240         1
# 9987        30605    South       Technology  Accessories   79.990         1
# 9988        30605    South       Technology       Phones  206.100         5
# 9989        33180    South        Furniture  Furnishings   25.248         3
# 9990        92627     West        Furniture  Furnishings   91.960         2
# 9991        92627     West       Technology       Phones  258.576         2
# 9992        92627     West  Office Supplies        Paper   29.600         4
# 9993        92683     West  Office Supplies   Appliances  243.160         2
#
#       Discount    Profit
# 9974       0.0    5.2332
# 9975       0.0    6.4128
# 9976       0.2   31.1980
# 9977       0.0    0.0000
# 9978       0.2    4.6816
# 9979       0.2  153.1152
# 9980       0.0   22.3548
# 9981       0.2    5.3690
# 9982       0.0   16.7132
# 9983       0.0   27.4344
# 9984       0.0   15.1200
# 9985       0.0   16.1240
# 9986       0.0   15.2208
# 9987       0.0   28.7964
# 9988       0.0   55.6470
# 9989       0.2    4.1028
# 9990       0.0   15.6332
# 9991       0.2   19.3932
# 9992       0.0   13.3200
# 9993       0.0   72.9480

# %%
#checking The Null Values
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 17

# %%
df = df.drop_duplicates()
df.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
# 5        90032   West        Furniture  Furnishings   48.8600         7
# 6        90032   West  Office Supplies          Art    7.2800         4
# 7        90032   West       Technology       Phones  907.1520         6
# 8        90032   West  Office Supplies      Binders   18.5040         3
# 9        90032   West  Office Supplies   Appliances  114.9000         5
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
# 5      0.00   14.1694
# 6      0.00    1.9656
# 7      0.20   90.7152
# 8      0.20    5.7825
# 9      0.00   34.4700

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.shape
# Out:
# (9977, 13)

# %%
#checking The UniQue Segment Data
df.Segment.unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df["Ship Mode"].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
df["Category"].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df["Sub-Category"].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %% [markdown]
# SalesSuper Store Has Main 3 Categories And 17 Sub Categories

# %%
df["Country"].unique()
# Out:
# array(['United States'], dtype=object)

# %% [markdown]
# ### Removing Data
#
# Here Country Is Same For All (United States) And Postal Code Is Not That Much Important For This Data Analysis

# %%
 
df = df.drop(["Country","Postal Code"],axis=1)

# %%
df.head()
# Out:
#         Ship Mode    Segment             City       State Region  \
# 0    Second Class   Consumer        Henderson    Kentucky  South
# 1    Second Class   Consumer        Henderson    Kentucky  South
# 2    Second Class  Corporate      Los Angeles  California   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida  South
#
#           Category Sub-Category     Sales  Quantity  Discount    Profit
# 0        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# Understanding The Data Patterns And Insights
#
# ### PairPlot

# %%
sns.pairplot(df)

# %% [markdown]
# ### Pairplot By Category

# %%
sns.pairplot(df,hue="Category")

# %%
newData = df.corr(numeric_only = True)
newData
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200722 -0.028311  0.479067
# Quantity  0.200722  1.000000  0.008678  0.066211
# Discount -0.028311  0.008678  1.000000 -0.219662
# Profit    0.479067  0.066211 -0.219662  1.000000

# %% [markdown]
# finding The Correlation of Columns And Visualizing The Data

# %%
sns.heatmap(newData,cmap="magma",annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# Visualization Data :
#  - Sales And Profit Are Moderately Correlated
#  - Sales And Quantity Are Moderately Correlated
#  - Discount And Profit Are Negatively Correlated

# %%
#Let's Check The Sales By Categories
df.groupby('Category')['Sales'].agg('sum').plot.bar()
# Out:
# <AxesSubplot: xlabel='Category'>

# %%
df.groupby('Category')['Profit'].agg('sum').plot.pie(autopct='%1.1f%%')
plt.title("Profits By Categories")
plt.legend()

# %%
categories = df.groupby('Category')['Sales'].agg('sum') 
profits = df.groupby('Category')['Profit'].agg('sum')
categories.plot(kind="bar", color="blue")
profits.plot(kind="bar", color="red")
plt.title("Sales vs Profits By Categories")
plt.xlabel("Category")
plt.ylabel("Sales/Profits")

plt.show()

# %% [markdown]
# Here Top Seller Categories are Technology, Furniture And Office Suppliers But Having The top Seller Furniture This Category Have Low Profits Margin Then The Office Suppliers

# %%
plt.figure(figsize=(14,12))
profits = df.groupby('Sub-Category')['Profit'].agg('sum')
profits.plot(kind="barh", )
plt.title("Top Performing Sub Categories")
plt.xlabel("Profits")
plt.ylabel("Sub Categories")

plt.show()

# %% [markdown]
# BookCases, Tables And Supplies Performance is Not Good Have a Negative Profits Margin

# %%
df.head()
# Out:
#         Ship Mode    Segment             City       State Region  \
# 0    Second Class   Consumer        Henderson    Kentucky  South
# 1    Second Class   Consumer        Henderson    Kentucky  South
# 2    Second Class  Corporate      Los Angeles  California   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida  South
#
#           Category Sub-Category     Sales  Quantity  Discount    Profit
# 0        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %%
plt.figure(figsize=(8,7))
sns.lineplot(x=df['Discount'] ,y=df['Profit'],data=df)
# Out:
# <AxesSubplot: xlabel='Discount', ylabel='Profit'>

# %% [markdown]
# We Need To Minimize High Discounts Rates On Products.

# %%
profits = df.groupby("Region").Profit.sum().nlargest(n=10)
sales = df.groupby("Region").Sales.sum().nlargest(n=10)
sales.plot(kind="bar", color="orange")
profits.plot(kind="bar", color="#4CAF50")
plt.title("Sales And Profits By Region")
plt.ylabel("Sales / Profits")
plt.plot()
# Out:
# []

# %% [markdown]
# Here Green Indicates The Profits And Orange Indicate The Sales. Here Central And South Region Giving Less Profits Margin So We Need To Remainted Marketing Stratigies in This Region

# %%
profits = df.groupby("State").Profit.sum()
sales = df.groupby("State").Sales.sum()

fig, ax = plt.subplots(figsize=(12,18))
sales.plot(kind="barh", ax=ax, color="orange")
profits.plot(kind="barh",ax=ax, color="#4CAF50")
plt.title("Sales And Profits By States")

plt.xlabel("Sales / Profits")
plt.ylabel("States")
ax.grid(axis='x')
plt.plot()
# Out:
# []

# %% [markdown]
# Here Texas , Pennsalvaniya , Ohio , North California, illinois , Florida & Colorado Are in Negative Profit Margin States.

# %%
 sns.barplot(x='Segment', y='Profit',data=df)
# Out:
# <AxesSubplot: xlabel='Segment', ylabel='Profit'>

# %%
 sns.barplot(x='Segment', y='Discount',data=df , palette="YlGnBu")
# Out:
# <AxesSubplot: xlabel='Segment', ylabel='Discount'>

# %% [markdown]
# From Segment Analysis  Most Profitable Segment is Home Office But Discounts Are Low in This Segment. So Discounts Must Be Minimized Or Removed On Consumer & Corporate Segment

# %% [markdown]
# # Conclusion
#   - The top profitable category is Technology & Office Supplies.
#   - Furniture categories have high sales but low profit margins.
#   - The top performing Regions are the West and East regions.
#   - The most profitable subcategories are copiers, phones, accessories, and paper.
#   - Washington, New York, and California are the top performing states.
#   - The Home Office and Corporate segments are the most profitable segments.
#
#   ### Need A Improvement On :
#     - Furniture is the highest selling category, but the profit margin is lower than that of office supplies. Therefore, the    selling strategy for the furniture category needs to be changed.
#     - Discounts should be minimized or removed, especially for consumer and corporate segments.
#     - Bookcases, tables, and supplies are not performing well and have negative profit margins. They need to be re-evaluated or removed from selling.
#     - The Central and South regions have poor profit margin performance. Therefore, the selling and marketing strategies for this region must be changed.
#     - Texas, Pennsylvania, Ohio, North California, Illinois, Florida, and Colorado are states with negative profit margins. Therefore, they must be given special consideration to develop new selling strategies or must be removed from these states.
